# %%
# Se importan las librerias a utilizar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Se hace la lectura del dataset del seminario y se obtiene su cabecera
dt = pd.read_csv('C:/Users/MauricioR/Documents/Pagos/MatriculaVIU/Maestria_Big_Data_Data_Science_Sep_2019/11MBIG_TFM/Datos/Data_frame.csv', ',', index_col='ID')
dt.head()
# Out:
#    Issue_type  Issue_Remaining_Estimate_Sum  Issue_Remaining_Estimate_Mean  \
# ID
# 1         Bug                         307.8                       0.094649
# 2         Bug                         307.8                       0.094649
# 3         Bug                         307.8                       0.094649
# 4         Bug                         307.8                       0.094649
# 5         Bug                         307.8                       0.094649
#
#     Issue_Remaining_Estimate_Median  Issue_Remaining_Estimate_Count  \
# ID
# 1                               0.0                            3252
# 2                               0.0                            3252
# 3                               0.0                            3252
# 4                               0.0                            3252
# 5                               0.0                            3252
#
#     Work_hours_Sum  Work_hours_Mean  Work_hours_Median  Work_hours_Count  \
# ID
# ...

# %%
def word_count(str):
    counts = 0
    words = str.split()

    for word in words:        
        counts += 1
    return counts

#print( word_count('the quick brown fox jumps over the lazy dog.'))
dt['Word_count_work_description'] = 0
for ind in dt.index:
    dt['Word_count_work_description'][ind] = word_count(str(dt['Work_description'][ind]))
    #print( word_count(str(dt['Work_description'][ind])))
dt.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#    Issue_type  Issue_Remaining_Estimate_Sum  Issue_Remaining_Estimate_Mean  \
# ID
# 1         Bug                         307.8                       0.094649
# 2         Bug                         307.8                       0.094649
# 3         Bug                         307.8                       0.094649
# 4         Bug                         307.8                       0.094649
# 5         Bug                         307.8                       0.094649
#
#     Issue_Remaining_Estimate_Median  Issue_Remaining_Estimate_Count  \
# ID
# 1                               0.0                            3252
# ...

# %%
dt = dt.reset_index()
dt.head()
# Out:
#    ID Issue_type  Issue_Remaining_Estimate_Sum  Issue_Remaining_Estimate_Mean  \
# 0   1        Bug                         307.8                       0.094649
# 1   2        Bug                         307.8                       0.094649
# 2   3        Bug                         307.8                       0.094649
# 3   4        Bug                         307.8                       0.094649
# 4   5        Bug                         307.8                       0.094649
#
#    Issue_Remaining_Estimate_Median  Issue_Remaining_Estimate_Count  \
# 0                              0.0                            3252
# 1                              0.0                            3252
# 2                              0.0                            3252
# 3                              0.0                            3252
# 4                              0.0                            3252
#
#    Work_hours_Sum  Work_hours_Mean  Work_hours_Median  Work_hours_Count  ...  \
# ...

# %%
dt2 = dt[['ID','Word_count_work_description']]
dt2.shape
# Out:
# (19222, 2)

# %%
dt2.to_csv (r'C:/Users/MauricioR/Documents/Pagos/MatriculaVIU/Maestria_Big_Data_Data_Science_Sep_2019/11MBIG_TFM/Datos/Data_frame2.csv', index = False, header=True)
